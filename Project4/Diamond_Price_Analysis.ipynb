# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Display graphs
# %matplotlib inline

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv("diamonds.csv")

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z  price
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757

# %%
df.sample(5)
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 20547   1.52  Very Good     D     SI2   61.2   63.0  7.31  7.39  4.50   8868
# 1795    1.03       Fair     G     SI1   66.1   56.0  6.26  6.20  4.12   3052
# 23439   1.70  Very Good     D     SI2   60.8   59.0  7.76  7.83  4.75  11431
# 18204   1.02    Premium     F     VS1   61.9   59.0  6.44  6.38  3.97   7389
# 17245   1.03      Ideal     F     VS2   62.0   57.0  6.40  6.48  3.99   6902

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.size
# Out:
# 539400

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z',
#        'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
#  9   price    53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#               carat         depth         table             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184      5.731157      5.734526
# std        0.474011      1.432621      2.234491      1.121761      1.142135
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z         price
# count  53940.000000  53940.000000
# mean       3.538734   3932.799722
# std        0.705699   3989.439738
# min        0.000000    326.000000
# 25%        2.910000    950.000000
# 50%        3.530000   2401.000000
# 75%        4.040000   5324.250000
# max       31.800000  18823.000000

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# Check Duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(146)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Analyze Numerical Features

# %%
df.select_dtypes(include=np.number)
# Out:
#        carat  depth  table     x     y     z  price
# 0       0.23   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31   63.3   58.0  4.34  4.35  2.75    335
# ...      ...    ...    ...   ...   ...   ...    ...
# 53935   0.72   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75   62.2   55.0  5.83  5.87  3.64   2757
#
# [53794 rows x 7 columns]

# %%
df.mean(numeric_only=True)
# Out:
# carat       0.797780
# depth      61.748080
# table      57.458109
# x           5.731214
# y           5.734653
# z           3.538714
# price    3933.065082
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# carat       0.70
# depth      61.80
# table      57.00
# x           5.70
# y           5.71
# z           3.53
# price    2401.00
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# carat       0.473390
# depth       1.429909
# table       2.233679
# x           1.120695
# y           1.141209
# z           0.705037
# price    3988.114460
# dtype: float64

# %% [markdown]
# Analyze Categorical Features

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['cut'].value_counts()

# %%
df['color'].value_counts()

df['clarity'].value_counts()
# Out:
# clarity
# SI1     13032
# VS2     12229
# SI2      9150
# VS1      8156
# VVS2     5056
# VVS1     3647
# IF       1784
# I1        740
# Name: count, dtype: int64

# %% [markdown]
# Compute Statistical Measures

# %%
df.mean(numeric_only=True)
# Out:
# carat       0.723744
# depth      61.754445
# table      57.422836
# x           5.583457
# y           5.586804
# z           3.448622
# price    3161.279982
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# carat       0.70
# depth      61.80
# table      57.00
# x           5.59
# y           5.58
# z           3.43
# price    2159.00
# dtype: float64

# %%
df.mode()
# Out:
#    carat    cut color clarity  depth  table     x     y    z  price
# 0    0.3  Ideal     G     SI1   62.0   56.0  4.37  4.34  2.7    605

# %%
df.std(numeric_only=True)
# Out:
# carat       0.383515
# depth       1.427967
# table       2.228483
# x           0.994177
# y           0.993285
# z           0.630035
# price    2765.577939
# dtype: float64

# %%
df.min(numeric_only=True)

df.max(numeric_only=True)
# Out:
# carat        3.65
# depth       79.00
# table       79.00
# x            9.54
# y           31.80
# z           31.80
# price    11888.00
# dtype: float64

# %% [markdown]
# Detect and Treat Outliers

# %%
Q1 = df['price'].quantile(0.25)

Q3 = df['price'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR

upper = Q3 + 1.5 * IQR

# %%
outliers = df[(df['price'] < lower) | (df['price'] > upper)]

outliers
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 23825   1.54    Premium     F     SI1   60.9   59.0  7.56  7.46  4.57  11897
# 23826   2.00    Premium     J     SI2   61.9   55.0  8.09  8.06  5.00  11899
# 23827   2.00    Premium     J     SI2   59.8   60.0  8.13  8.09  4.85  11899
# 23828   1.56    Premium     F     SI1   60.7   59.0  7.55  7.45  4.55  11901
# 23829   2.01    Premium     F     SI2   62.0   60.0  7.88  7.82  4.87  11903
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  7.95  8.00  5.01  18803
# 27746   2.07      Ideal     G     SI2   62.5   55.0  8.20  8.13  5.11  18804
# 27747   1.51      Ideal     G      IF   61.7   55.0  7.37  7.41  4.56  18806
# 27748   2.00  Very Good     G     SI1   63.5   56.0  7.90  7.97  5.04  18818
# 27749   2.29    Premium     I     VS2   60.8   60.0  8.50  8.47  5.16  18823
#
# [3523 rows x 10 columns]

# %% [markdown]
# Treat outlier

# %%
df = df[(df["price"] >= lower) & (df["price"] <= upper)]

# %% [markdown]
# Correlation Analysis

# %%
correlation = df.corr(numeric_only=True)

correlation
# Out:
#           carat     depth     table         x         y         z     price
# carat  1.000000  0.027861  0.181091  0.975380  0.951908  0.953542  0.921548
# depth  0.027861  1.000000 -0.297669 -0.025348 -0.029389  0.094757 -0.011048
# table  0.181091 -0.297669  1.000000  0.194855  0.183231  0.150270  0.126566
# x      0.975380 -0.025348  0.194855  1.000000  0.974592  0.970686  0.884504
# y      0.951908 -0.029389  0.183231  0.974592  1.000000  0.951844  0.865395
# z      0.953542  0.094757  0.150270  0.970686  0.951844  1.000000  0.861208
# price  0.921548 -0.011048  0.126566  0.884504  0.865395  0.861208  1.000000

# %% [markdown]
# Data Visualization

# %% [markdown]
# Histogram

# %%
plt.figure(figsize=(8,5))
plt.hist(df['price'], bins=30)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Box plot

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y=df['price'])
plt.title("Price Boxplot")
plt.show()

# %% [markdown]
# Scatter plot

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['carat'], df['price'])
plt.xlabel("Carat")
plt.ylabel("Price")
plt.title("Carat vs Price")
plt.show()

# %% [markdown]
# Bar chart

# %%
avg_price = df.groupby('cut')['price'].mean()

avg_price.plot(kind='bar')

plt.title("Average Price by Cut")

plt.xlabel("Cut")

plt.ylabel("Average Price")

plt.show()

# %% [markdown]
# Count plot

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='cut', data=df)
plt.title("Diamond Cut Count")
plt.show()

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize=(10,8))

sns.heatmap(correlation,
            annot=True,
            cmap='coolwarm')

plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# Group Analysis

# %%
df.groupby("cut")["price"].mean()
# Out:
# cut
# Fair         3658.691127
# Good         3288.790884
# Ideal        2814.281056
# Premium      3542.385163
# Very Good    3245.936445
# Name: price, dtype: float64

# %%
df.groupby("color")["price"].mean()
# Out:
# color
# D    2698.364982
# E    2619.863110
# F    3081.483448
# G    3238.427933
# H    3570.324491
# I    3740.641423
# J    4025.761419
# Name: price, dtype: float64

# %%
df.groupby("clarity")["price"].mean()
# Out:
# clarity
# I1      3707.865014
# IF      2132.584423
# SI1     3293.074812
# SI2     3855.528060
# VS1     3158.435467
# VS2     3118.371915
# VVS1    2124.172003
# VVS2    2791.686234
# Name: price, dtype: float64
